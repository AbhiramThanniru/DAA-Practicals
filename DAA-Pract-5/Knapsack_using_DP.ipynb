# %%
import time

def knapsack(n, weights, values, capacity):
    dp = [[0 for _ in range(capacity + 1)] for _ in range(n + 1)]

    for i in range(1, n + 1):
        for w in range(1, capacity + 1):

            if weights[i - 1] <= w:
                dp[i][w] = max(
                    values[i - 1] + dp[i - 1][w - weights[i - 1]],
                    dp[i - 1][w]
                )
            else:
                dp[i][w] = dp[i - 1][w]

    return dp[n][capacity]


# Input
n = int(input("Enter number of items: "))

weights = []
values = []

for i in range(n):
    weight, value = map(int, input(
        f"Enter weight and value of item {i + 1}: "
    ).split())

    weights.append(weight)
    values.append(value)

capacity = int(input("Enter knapsack capacity: "))

start=time.time()

result = knapsack(n, weights, values, capacity)

end=time.time()

print("Maximum value:", result)
print("Execution time: ",end - start," seconds")
print("Time Complexity: O(n x W)")
print("Space Complexity: O(n x W)")
# Out:
# Enter number of items: 4
# Enter weight and value of item 1: 1 5
# Enter weight and value of item 2: 2 3
# Enter weight and value of item 3: 5 1
# Enter weight and value of item 4: 3 4
# Enter knapsack capacity: 5
# Maximum value: 9
# Execution time:  0.0001354217529296875  seconds
# Time Complexity: O(n x W)
# Space Complexity: O(n x W)
